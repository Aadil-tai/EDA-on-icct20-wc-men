# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# **Importing all files of Dataset**

# %%
batting=pd.read_csv('ICCT202022)/batting_card.csv')
batting.sample(5)
# Out:
#      season  match_id match_name home_team away_team                   venue  \
# 71     2022   1298175  BAN v PAK       BAN       PAK           Adelaide Oval
# 512    2022   1298145   IRE v WI        WI       IRE  Bellerive Oval, Hobart
# 69     2022   1298175  BAN v PAK       BAN       PAK           Adelaide Oval
# 104    2022   1298173   ENG v SL        SL       ENG   Sydney Cricket Ground
# 272    2022   1298163  NED v PAK       NED       PAK           Perth Stadium
#
#          city    country current_innings  innings_id  ... fours sixes  \
# 71   Adelaide  Australia             PAK           2  ...     0     0
# 512    Hobart  Australia              WI           1  ...     0     0
# 69   Adelaide  Australia             PAK           2  ...     2     0
# 104    Sydney  Australia             ENG           2  ...     1     0
# 272     Perth  Australia             NED           1  ...     0     0
#
#      strikeRate  captain isNotOut                runningScore  runningOver  \
# ...

# %%
bowling=pd.read_csv('ICCT202022)/bowling_card.csv')
bowling.sample(5)
# Out:
#      season  match_id match_name home_team away_team bowling_team  \
# 306    2022   1298151  BAN v NED       BAN       NED          BAN
# 496    2022   1298135   NAM v SL       NAM        SL          NAM
# 485    2022   1298136  NED v UAE       UAE       NED          UAE
# 58     2022   1298175  BAN v PAK       BAN       PAK          BAN
# 286    2022   1298153   AUS v SL        SL       AUS           SL
#
#                                         venue      city    country  \
# 306                    Bellerive Oval, Hobart    Hobart  Australia
# 496  Simonds Stadium, South Geelong, Victoria   Geelong  Australia
# 485  Simonds Stadium, South Geelong, Victoria   Geelong  Australia
# 58                              Adelaide Oval  Adelaide  Australia
# 286                             Perth Stadium     Perth  Australia
#
#      innings_id  ... conceded wickets  economyRate  dots  foursConceded  \
# 306           2  ...       29       1         9.66     5              2
# ...

# %%
details=pd.read_csv('ICCT202022)/details.csv')
details.sample(5)
# Out:
#       comment_id  match_id match_name home_team away_team current_innings  \
# 9300      214010   1298137  SCOT v WI      SCOT        WI              WI
# 3088       13020   1298166   AFG v SL       AFG        SL             AFG
# 3093       14010   1298166   AFG v SL       AFG        SL             AFG
# 1996      114010   1298171   IRE v NZ        NZ       IRE              NZ
# 9724       24030   1298135   NAM v SL       NAM        SL              SL
#
#       innings_id  over  ball  runs  ... wicket_id  wkt_batsman_name  \
# 9300           2    15     1     1  ...       NaN               NaN
# 3088           1     4     2     4  ...       NaN               NaN
# 3093           1     5     1     4  ...       NaN               NaN
# 1996           1    15     1     1  ...       NaN               NaN
# 9724           2     5     2     0  ...       NaN               NaN
#
#       wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls wkt_text  \
# ...

# %%
summary=pd.read_csv('ICCT202022)/summary.csv')
batting.sample(5)
# Out:
#      season  match_id   match_name home_team away_team  \
# 340    2022   1298157  INDIA v NED     INDIA       NED
# 335    2022   1298158    PAK v ZIM       ZIM       PAK
# 132    2022   1298171     IRE v NZ        NZ       IRE
# 620    2022   1298139    NAM v NED       NAM       NED
# 325    2022   1298158    PAK v ZIM       ZIM       PAK
#
#                                         venue      city    country  \
# 340                     Sydney Cricket Ground    Sydney  Australia
# 335                             Perth Stadium     Perth  Australia
# 132                             Adelaide Oval  Adelaide  Australia
# 620  Simonds Stadium, South Geelong, Victoria   Geelong  Australia
# 325                             Perth Stadium     Perth  Australia
#
#     current_innings  innings_id  ... fours sixes  strikeRate  captain  \
# 340           INDIA           1  ...     4     3      135.89     True
# 335             PAK           2  ...     0     0        0.00    False
# ...

# %% [markdown]
# **T20 WC participated Teams**

# %% [markdown]
# **Highest Score of Every Indian Batsman**

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='INDIA',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                      batsman1_runs
# batsman1_name
# Virat Kohli                     82
# Suryakumar Yadav                68
# Hardik Pandya                   63
# Rohit Sharma                    53
# KL Rahul                        51
# Ravichandran Ashwin             13

# %%
details.columns
# Out:
# Index(['comment_id', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt', 'text', 'preText', 'postText'],
#       dtype='object')

# %%
batting.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
#        'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
#        'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
#        'captain', 'isNotOut', 'runningScore', 'runningOver', 'shortText',
#        'commentary', 'link'],
#       dtype='object')

# %% [markdown]
# bowlings column

# %%
bowling.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'bowling_team', 'venue', 'city', 'country', 'innings_id', 'name',
#        'fullName', 'overs', 'maidens', 'conceded', 'wickets', 'economyRate',
#        'dots', 'foursConceded', 'sixesConceded', 'wides', 'noballs', 'captain',
#        'href'],
#       dtype='object')

# %% [markdown]
# **Highest Score of Every England Batsman**

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='ENG',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                   batsman1_runs
# batsman1_name
# Alex Hales                   86
# Jos Buttler                  80
# Ben Stokes                   52
# Dawid Malan                  35
# Liam Livingstone             29
# Moeen Ali                    24

# %% [markdown]
# **Highest Score of Every australia Batsman**

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='AUS',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                 batsman1_runs
# batsman1_name
# Aaron Finch                63
# Marcus Stoinis             59
# Glenn Maxwell              54
# Mitchell Marsh             45
# David Warner               25
# Pat Cummins                21

# %% [markdown]
# **Highest Score of Every Pakistan Batsman**

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='PAK',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                  batsman1_runs
# batsman1_name
# Mohammad Rizwan             57
# Babar Azam                  53
# Shadab Khan                 52
# Shan Masood                 52
# Iftikhar Ahmed              51
# Mohammad Haris              31

# %% [markdown]
# to add more column like to describe team india is win or loss

# %%
IND_results=summary.loc[(summary['home_team']=='INDIA') | (summary['away_team']=='INDIA'), :].copy()
IND_results.columns
# Out:
# Index(['season', 'id', 'name', 'short_name', 'description', 'home_team',
#        'away_team', 'toss_won', 'decision', '1st_inning_score',
#        '2nd_inning_score', 'home_score', 'away_score', 'winner', 'result',
#        'start_date', 'end_date', 'venue_id', 'venue_name', 'home_captain',
#        'away_captain', 'pom', 'points', 'super_over', 'home_overs',
#        'home_runs', 'home_wickets', 'home_boundaries', 'away_overs',
#        'away_runs', 'away_wickets', 'away_boundaries', 'highlights',
#        'home_key_batsman', 'home_key_bowler', 'home_playx1', 'away_playx1',
#        'away_key_batsman', 'away_key_bowler', 'match_days', 'umpire1',
#        'umpire2', 'tv_umpire', 'referee', 'reserve_umpire'],
#       dtype='object')

# %%
IND_results['Vs'] = IND_results['home_team'] + IND_results['away_team']
IND_results['Vs'] = IND_results['Vs'].str.replace('INDIA', '')

IND_results.drop(['home_team','away_team','reserve_umpire','description','match_days', 'umpire1','umpire2', 'tv_umpire', 'referee'], axis=1, inplace=True)

# %% [markdown]
# **Since this is a INDIA dataframe, it'd make more sense to us if we have a column which tells us whether INDIA won or lost the match. And so we do this by applying a lambda function on the 'WinningTeam' column.**

# %%
IND_results['WinningTeam'] = IND_results['winner'].apply(lambda x: 'Win' if x=='INDIA' else 'Loss')
# IND_results.set_index('id', inplace=True)
IND_results.reset_index(inplace=True)

# %% [markdown]
# This code creates a new column called WinningTeam in the IND_results dataframe, which indicates whether India won or lost the match. The apply() method is used to apply a lambda function on each value in the winner column. If the value is equal to 'INDIA', then the lambda function returns 'Win', otherwise it returns 'Loss'. The result of the lambda function is then stored in the WinningTeam column.

# %%
IND_results.head(15)
# Out:
#    index  season       id                  name   short_name    toss_won  \
# 0      1  2022.0  1298178       England v India  ENG v INDIA     England
# 1      3  2022.0  1298176      India v Zimbabwe  INDIA v ZIM       India
# 2     10  2022.0  1298169    Bangladesh v India  BAN v INDIA  Bangladesh
# 3     15  2022.0  1298164  India v South Africa   INDIA v SA       India
# 4     22  2022.0  1298157   India v Netherlands  INDIA v NED       India
# 5     29  2022.0  1298150      India v Pakistan  INDIA v PAK       India
#
#      decision 1st_inning_score 2nd_inning_score home_score  ...  \
# 0  BOWL FIRST            168/6            170/0      170/0  ...
# 1   BAT FIRST            186/5              115      186/5  ...
# 2  BOWL FIRST            184/6            145/6      145/6  ...
# 3   BAT FIRST            133/9            137/5      133/9  ...
# 4   BAT FIRST            179/2            123/9      179/2  ...
# 5  BOWL FIRST            159/8            160/6      160/6  ...
#
# ...

# %% [markdown]
# **Let's try and find out INDIA's results across all the venues they played in:**

# %%
ind_venue_wise1 = IND_results.groupby(['venue_name','WinningTeam']).count()['name']
ind_venue_wise1 = ind_venue_wise1.unstack()
ind_venue_wise1.sort_values(by=['Loss','Win'],ascending=[False,True],inplace=True)
print(ind_venue_wise1)
# Out:
# WinningTeam               Loss  Win
# venue_name
# Adelaide Oval              1.0  1.0
# Perth Stadium              1.0  NaN
# Sydney Cricket Ground      NaN  1.0
# Melbourne Cricket Ground   NaN  2.0

# %%
plt.xkcd()
plt.figure(figsize=(35,6))
ind_venue_wise1.plot(kind='barh' , stacked=True, color=['Tomato','green'])
plt.title("INDIA's results at different venues")
plt.legend(loc=7)
plt.xlabel('Wins and losses', fontsize=20)
plt.ylabel('Venues', fontsize=20)

# plt.savefig('Venue-wise results', bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# We can make an important observations from the plot:
#
# INDIA has won all the games they played inMelbourne Cricket Ground and Sydney Cricket Ground.
#
# Similarly, we do the same to analyse the toss results of INDIA:
#
# First, we apply a lambda function on the 'Toss' column to know if INDIA has won or lost the toss. Then we rename the column 'WinningTeam' to 'Result'.

# %%
IND_results['Toss'] = IND_results['toss_won'].apply(lambda x: 'Won the toss' if x=='India' else 'Lost the toss')
IND_results.rename(columns={'WinningTeam':'Result'}, inplace=True)
IND_results.drop('toss_won', axis=1)
IND_results
# Out:
#    index  season       id                  name   short_name    toss_won  \
# 0      1  2022.0  1298178       England v India  ENG v INDIA     England
# 1      3  2022.0  1298176      India v Zimbabwe  INDIA v ZIM       India
# 2     10  2022.0  1298169    Bangladesh v India  BAN v INDIA  Bangladesh
# 3     15  2022.0  1298164  India v South Africa   INDIA v SA       India
# 4     22  2022.0  1298157   India v Netherlands  INDIA v NED       India
# 5     29  2022.0  1298150      India v Pakistan  INDIA v PAK       India
#
#      decision 1st_inning_score 2nd_inning_score home_score  ...  \
# 0  BOWL FIRST            168/6            170/0      170/0  ...
# 1   BAT FIRST            186/5              115      186/5  ...
# 2  BOWL FIRST            184/6            145/6      145/6  ...
# 3   BAT FIRST            133/9            137/5      133/9  ...
# 4   BAT FIRST            179/2            123/9      179/2  ...
# 5  BOWL FIRST            159/8            160/6      160/6  ...
#
# ...

# %%
IND_results['First Innings'] = np.where(IND_results['toss_won']=='India',IND_results['decision'],''+IND_results['decision'])
IND_results['First Innings'] = IND_results['First Innings'].str.replace('BAT FIRST','bat')
IND_results['First Innings'] = IND_results['First Innings'].str.replace('BOWL FIRST','field')
IND_results.drop('toss_won', axis=1, inplace=True)
IND_results.drop('decision', axis=1, inplace=True)
IND_results
# Out:
#    index  season       id                  name   short_name 1st_inning_score  \
# 0      1  2022.0  1298178       England v India  ENG v INDIA            168/6
# 1      3  2022.0  1298176      India v Zimbabwe  INDIA v ZIM            186/5
# 2     10  2022.0  1298169    Bangladesh v India  BAN v INDIA            184/6
# 3     15  2022.0  1298164  India v South Africa   INDIA v SA            133/9
# 4     22  2022.0  1298157   India v Netherlands  INDIA v NED            179/2
# 5     29  2022.0  1298150      India v Pakistan  INDIA v PAK            159/8
#
#   2nd_inning_score home_score away_score winner  ...  \
# 0            170/0      170/0      168/6    ENG  ...
# 1              115      186/5        115  INDIA  ...
# 2            145/6      145/6      184/6  INDIA  ...
# 3            137/5      133/9      137/5     SA  ...
# 4            123/9      179/2      123/9  INDIA  ...
# 5            160/6      160/6      159/8  INDIA  ...
#
# ...

# %% [markdown]
# First, let's plot a bar graph to see how many times did INDIA bat/field first after winning/losing the toss.

# %%
pd.crosstab(IND_results['Toss'], IND_results['First Innings']).plot(kind='bar', stacked=True)
plt.title("IND's toss results")
plt.legend(fontsize='small',title_fontsize='x-small', title='First Innings')
# plt.savefig('Toss Results.png', bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
toss_stats = IND_results[['Result','Toss','First Innings']].groupby(['Toss','Result']).count()
toss_stats
# Out:
#                       First Innings
# Toss          Result
# Lost the toss Loss                1
#               Win                 1
# Won the toss  Loss                1
#               Win                 3

# %%
import matplotlib.pyplot as plt

# Create a stacked bar chart
toss_stats.unstack().plot(kind='bar', stacked=True)

# Set the chart title and axis labels
plt.title('Toss and Match Results')
plt.xlabel('Toss Result')
plt.ylabel('Number of Matches')

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# We next check if winning the toss had any implications on INDIA's results.

# %%
pd.crosstab(IND_results['Toss'],IND_results['Result']).plot(kind='bar',stacked=True)
plt.title('First Innings vs Match Result')
plt.legend(fontsize='x-small')
plt.ylabel('Count')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# it should be interesting to see how INDIA's top run getters have fared through the season. It'll give us a perspective on who was more consistent than the rest.
#
# Let's first find out who are the top 5 run getters for INDIA and store it in a dataframe.

# %%
top_runs = details[['batsman1_name','runs']].loc[details['current_innings']=='INDIA'].groupby('batsman1_name').sum().sort_values(by='runs',ascending=False)[0:5]
top_run_getters = top_runs.index
top_run_getters
# Out:
# Index(['Virat Kohli', 'Suryakumar Yadav', 'Hardik Pandya', 'KL Rahul',
#        'Rohit Sharma'],
#       dtype='object', name='batsman1_name')

# %%
top5_ind = details[['match_name','batsman1_name','batsman1_runs']].loc[(details['current_innings']=='INDIA') & (details['batsman1_name'].isin(top_run_getters))].groupby(['match_name','batsman1_name']).max().unstack()
top5_ind = top5_ind.cumsum()
top5_ind
# Out:
#               batsman1_runs
# batsman1_name Hardik Pandya KL Rahul Rohit Sharma Suryakumar Yadav Virat Kohli
# match_name
# BAN v INDIA             5.0     50.0          2.0             30.0        64.0
# ENG v INDIA            68.0     55.0         29.0             44.0       114.0
# INDIA v NED             NaN     64.0         82.0             95.0       176.0
# INDIA v PAK           108.0     68.0         86.0            110.0       258.0
# INDIA v SA            110.0     77.0        101.0            178.0       270.0
# INDIA v ZIM           128.0    128.0        116.0            233.0       296.0

# %%
ind_pak_matches = summary[((summary['home_team']=='INDIA') & (summary['away_team']=='PAK')) | ((summary['home_team']=='PAK') & (summary['away_team']=='INDIA'))]

# %%
IND_results
# Out:
#    index  season       id                  name   short_name 1st_inning_score  \
# 0      1  2022.0  1298178       England v India  ENG v INDIA            168/6
# 1      3  2022.0  1298176      India v Zimbabwe  INDIA v ZIM            186/5
# 2     10  2022.0  1298169    Bangladesh v India  BAN v INDIA            184/6
# 3     15  2022.0  1298164  India v South Africa   INDIA v SA            133/9
# 4     22  2022.0  1298157   India v Netherlands  INDIA v NED            179/2
# 5     29  2022.0  1298150      India v Pakistan  INDIA v PAK            159/8
#
#   2nd_inning_score home_score away_score winner  ...  \
# 0            170/0      170/0      168/6    ENG  ...
# 1              115      186/5        115  INDIA  ...
# 2            145/6      145/6      184/6  INDIA  ...
# 3            137/5      133/9      137/5     SA  ...
# 4            123/9      179/2      123/9  INDIA  ...
# 5            160/6      160/6      159/8  INDIA  ...
#
# ...

# %%
ind_ENG_matches = summary[((summary['home_team']=='INDIA') & (summary['away_team']=='ENG')) | ((summary['home_team']=='ENG') & (summary['away_team']=='INDIA'))]

# %%
ind_ENG_matches.head(15)
# Out:
#    season       id             name   short_name  \
# 1  2022.0  1298178  England v India  ENG v INDIA
#
#                                          description home_team away_team  \
# 1  2nd Semi-Final (N), ICC Men's T20 World Cup at...       ENG     INDIA
#
#   toss_won    decision 1st_inning_score  ...  \
# 1  England  BOWL FIRST            168/6  ...
#
#                                          home_playx1  \
# 1  Jos Buttler (WK),Alex Hales (UKN),Phil Salt (U...
#
#                                          away_playx1  \
# 1  KL Rahul (UKN),Rohit Sharma (UKN),Virat Kohli ...
#
#             away_key_batsman                  away_key_bowler  \
# 1  Hardik Pandya,Virat Kohli  Hardik Pandya,Bhuvneshwar Kumar
#
#                                        match_days           umpire1  \
# 1  10 November 2022 - night match (20-over match)  Kumar Dharmasena
#
#         umpire2       tv_umpire     referee reserve_umpire
# 1  Paul Reiffel  Chris Gaffaney  David Boon     Rod Tucker
#
# ...

# %%
print(summary.columns)
# Out:
# Index(['season', 'id', 'name', 'short_name', 'description', 'home_team',
#        'away_team', 'toss_won', 'decision', '1st_inning_score',
#        '2nd_inning_score', 'home_score', 'away_score', 'winner', 'result',
#        'start_date', 'end_date', 'venue_id', 'venue_name', 'home_captain',
#        'away_captain', 'pom', 'points', 'super_over', 'home_overs',
#        'home_runs', 'home_wickets', 'home_boundaries', 'away_overs',
#        'away_runs', 'away_wickets', 'away_boundaries', 'highlights',
#        'home_key_batsman', 'home_key_bowler', 'home_playx1', 'away_playx1',
#        'away_key_batsman', 'away_key_bowler', 'match_days', 'umpire1',
#        'umpire2', 'tv_umpire', 'referee', 'reserve_umpire'],
#       dtype='object')

# %%
match_id = 1298150
# Group the data by match ID and team name, and sum the runs column
runs_by_team = batting.groupby(['match_id', 'home_team','away_team','name'])['runs'].sum()

# Print the results
print(runs_by_team)
# Out:
# match_id  home_team  away_team  name
# 1298135   NAM        SL         BKG Mendis              6
#                                 C Karunaratne           5
#                                 D Wiese                 0
#                                 D la Cock               9
#                                 DM de Silva            12
#                                                        ..
# 1298179   PAK        ENG        Mohammad Wasim(1)       4
#                                 PD Salt                10
#                                 Shadab Khan            20
#                                 Shaheen Shah Afridi     5
#                                 Shan Masood            38
# Name: runs, Length: 699, dtype: int64

# %%
from tabulate import tabulate

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Indian batsmen in the match against Pakistan
india_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'INDIA') & (batting['innings_id'] == 2), ['name', 'fullName', 'runs']]

# Get the details of Pakistan batsmen in the match against India
pakistan_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'INDIA') & (batting['innings_id'] == 1), ['name', 'fullName', 'runs']]

# Define table headers
headers = ['Name', 'Full Name', 'Runs']

# Print India batsmen data
print("India Batsmen:")
print(tabulate(india_batsmen, headers=headers, tablefmt='fancy_grid'))

# Print Pakistan batsmen data
print("Pakistan Batsmen:")
print(tabulate(pakistan_batsmen, headers=headers, tablefmt='fancy_grid'))
# Out:
# India Batsmen:
# ╒═════╤════════════╤═════════════════════╤════════╕
# │     │ Name       │ Full Name           │   Runs │
# ╞═════╪════════════╪═════════════════════╪════════╡
# │ 442 │ KL Rahul   │ KL Rahul            │      4 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 443 │ RG Sharma  │ Rohit Sharma        │      4 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 444 │ V Kohli    │ Virat Kohli         │     82 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 445 │ SA Yadav   │ Suryakumar Yadav    │     15 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 446 │ AR Patel   │ Axar Patel          │      2 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 447 │ HH Pandya  │ Hardik Pandya       │     40 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 448 │ KD Karthik │ Dinesh Karthik      │      1 │
# ├─────┼────────────┼─────────────────────┼────────┤
# │ 449 │ R Ashwin   │ Ravichandran Ashwin │      1 │
# ...

# %%
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Indian batsmen in the match against Pakistan
india_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'INDIA') & (batting['innings_id'] == 2), ['name', 'runs']]

# Get the details of Pakistan batsmen in the match against India
#pakistan_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'PAK') & (batting['innings_id'] == 1), ['name', 'runs']]

# Concatenate the data for Indian and Pakistan batsmen
batsmen_data = pd.concat([india_batsmen])

# Group the data by batsman name and sum the runs column
runs_by_batsman = batsmen_data.groupby('name')['runs'].sum()

# Create a bar chart of the runs scored by each batsman
fig, ax = plt.subplots()
ax.bar(runs_by_batsman.index, runs_by_batsman.values)

# Set the chart title and axis labels
ax.set_title('Runs scored by each batsman in the India ')
ax.set_xlabel('Batsman')
ax.set_ylabel('Runs')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Pakistan batsmen in the match against India
pakistan_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'INDIA') & (batting['innings_id'] == 1), ['name', 'runs']]

# Group the data by batsman name and sum the runs column
runs_by_batsman = pakistan_batsmen.groupby('name')['runs'].sum()

# Create a bar chart of the runs scored by each batsman
fig, ax = plt.subplots()
ax.bar(runs_by_batsman.index, runs_by_batsman.values)

# Set the chart title and axis labels
ax.set_title('Runs scored by each batsman in the Pakistan')
ax.set_xlabel('Batsman')
ax.set_ylabel('Runs')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Pakistan bowlers in the match against India
pakistan_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 2), ['name', 'conceded']]

# Group the data by bowler name and sum the runs_conceded column
runs_by_bowler = pakistan_bowlers.groupby('name')['conceded'].sum()

# Create a bar chart of the runs conceded by each bowler
fig, ax = plt.subplots()
ax.bar(runs_by_bowler.index, runs_by_bowler.values)

# Set the chart title and axis labels
ax.set_title('Runs conceded by Pakistans bowler in the Pakistan vs India match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Runs conceded')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Pakistan bowlers in the match against India
pakistan_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 1), ['name', 'conceded']]

# Group the data by bowler name and sum the runs_conceded column
runs_by_bowler = pakistan_bowlers.groupby('name')['conceded'].sum()

# Create a bar chart of the runs conceded by each bowler
fig, ax = plt.subplots()
ax.bar(runs_by_bowler.index, runs_by_bowler.values)

# Set the chart title and axis labels
ax.set_title('Runs conceded by Indian bowlers in the Pakistan vs India match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Runs conceded')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Indian bowlers in the match against Pakistan
india_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 1), ['name', 'wickets']]

# Get the details of Pakistani bowlers in the match against India
pakistan_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 2), ['name', 'wickets']]

# Group the data by bowler name and sum the wickets column
wickets_by_bowler_india = india_bowlers.groupby('name')['wickets'].sum()
wickets_by_bowler_pakistan = pakistan_bowlers.groupby('name')['wickets'].sum()

# Create a bar chart of the wickets taken by each bowler
fig, ax = plt.subplots()
india_bars = ax.bar(wickets_by_bowler_india.index, wickets_by_bowler_india.values, label='India' , color='blue')
pakistan_bars = ax.bar(wickets_by_bowler_pakistan.index, wickets_by_bowler_pakistan.values, label='Pakistan', color='green')

# Set the chart title and axis labels
ax.set_title('Wickets taken by each bowler in the match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Wickets')
ax.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Add text labels to each bar
for bar in india_bars:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height, str(int(height)), ha='center', va='bottom', fontsize=8)

for bar in pakistan_bars:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height, str(int(height)), ha='center', va='bottom', fontsize=8)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Indian bowlers in the match against Pakistan
india_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 1), ['name', 'wickets']]

# Get the details of Pakistani bowlers in the match against India
pakistan_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 2), ['name', 'wickets']]

# Group the data by bowler name and sum the wickets column
wickets_by_bowler_india = india_bowlers.groupby('name')['wickets'].sum()
wickets_by_bowler_pakistan = pakistan_bowlers.groupby('name')['wickets'].sum()

# Create a bar chart of the wickets taken by each bowler for India
fig, ax = plt.subplots()
ax.bar(wickets_by_bowler_india.index, wickets_by_bowler_india.values, label='India', color='blue')

# Create a bar chart of the wickets taken by each bowler for Pakistan
ax.bar(wickets_by_bowler_pakistan.index, wickets_by_bowler_pakistan.values, label='Pakistan', color='green')

# Set the chart title and axis labels
ax.set_title('Wickets taken by each team\'s bowlers in the match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Wickets')
ax.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the match ID for the India vs Pakistan match
match_id = 1298150

# Get the details of Indian bowlers in the match against Pakistan
india_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 1), ['name', 'foursConceded','sixesConceded']]

# Get the details of Pakistani bowlers in the match against India
pakistan_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'INDIA') & (bowling['innings_id'] == 2), ['name', 'foursConceded' , 'sixesConceded']]

# Group the data by bowler name and sum the wickets column
wickets_by_bowler_india = india_bowlers.groupby('name')['foursConceded'].sum()
wickets_by_bowler_pakistan = pakistan_bowlers.groupby('name')['foursConceded'].sum()

# Create a bar chart of the wickets taken by each bowler for India
fig, ax = plt.subplots()
ax.bar(wickets_by_bowler_india.index, wickets_by_bowler_india.values, label='India', color='blue')

# Create a bar chart of the wickets taken by each bowler for Pakistan
ax.bar(wickets_by_bowler_pakistan.index, wickets_by_bowler_pakistan.values, label='Pakistan', color='green')

# Set the chart title and axis labels
ax.set_title('Wickets taken by each team\'s bowlers in the match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Wickets')
ax.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
# Select the match ID
match_id = 1298150

# Get the details of all bowlers who played in the match
bowlers = bowling.loc[(bowling['match_id'] == match_id), ['name', 'overs', 'conceded', 'foursConceded' , 'sixesConceded']]

# Calculate the number of fours and sixes conceded by each bowler
fours_by_bowler = bowlers.groupby('name')['foursConceded'].sum()
sixes_by_bowler = bowlers.groupby('name')['sixesConceded'].sum()

# Calculate the number of overs bowled by each bowler
overs_by_bowler = bowlers.groupby('name')['overs'].sum()

# Merge the results into a single DataFrame
result = pd.concat([fours_by_bowler, sixes_by_bowler, overs_by_bowler], axis=1, sort=False)
result.columns = ['foursConceded', 'sixesConceded', 'overs']

# Print the result
print(result)
# Out:
#                      foursConceded  sixesConceded  overs
# name
# AR Patel                         0              3    1.0
# Arshdeep Singh                   3              1    4.0
# B Kumar                          1              1    4.0
# HH Pandya                        4              0    4.0
# Haris Rauf                       2              2    4.0
# Mohammad Nawaz(3)                0              4    4.0
# Mohammed Shami                   4              0    4.0
# Naseem Shah                      1              0    4.0
# R Ashwin                         0              1    3.0
# Shadab Khan                      2              0    4.0
# Shaheen Shah Afridi              4              0    4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Select the match ID
match_id = 1298150

# Get the details of all bowlers who played in the match
bowlers = bowling.loc[(bowling['match_id'] == match_id), ['name', 'overs', 'conceded', 'foursConceded', 'sixesConceded' , 'dots' , 'economyRate']]

# Calculate the number of fours and sixes conceded by each bowler
fours_by_bowler = bowlers.groupby('name')['foursConceded'].sum()
sixes_by_bowler = bowlers.groupby('name')['sixesConceded'].sum()
dots_by_bowler = bowlers.groupby('name')['dots'].sum()
economy_by_bowler = bowlers.groupby('name')['economyRate'].sum()

# Calculate the number of overs bowled by each bowler
overs_by_bowler = bowlers.groupby('name')['overs'].sum()

# Merge the results into a single DataFrame
result = pd.concat([fours_by_bowler, sixes_by_bowler, overs_by_bowler ,dots_by_bowler,economy_by_bowler], axis=1, sort=False)
result.columns = ['Fours Conceded', 'Sixes Conceded', 'Overs Bowled' , 'dots bowled' , 'Economy']

# Format the data for display
result = result.style.format({
    'Fours Conceded': '{:.0f}',
    'Sixes Conceded': '{:.0f}',
    'Overs Bowled': '{:.1f}',
    'dots Bowled': '{:.1f}'
})

# Set table properties
result.set_properties(**{'text-align': 'center'})
result.set_table_styles([
    {'selector': 'th', 'props': [('font-weight', 'bold'), ('font-size', '12pt')]},
    {'selector': 'td', 'props': [('font-size', '11pt')]}
])

# Display the table
display(result)
# Create the plot for India
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(result.loc[('INDIA'), :].index, result.loc[('INDIA'), :]['Fours Conceded'], width=0.4, label='Fours')
ax.bar(result.loc[('INDIA'), :].index, result.loc[('INDIA'), :]['Sixes Conceded'], width=0.4, label='Sixes', bottom=result.loc[('INDIA'), :]['Fours Conceded'])
ax.set_ylabel('Number of runs')
ax.set_xlabel('Bowler')
ax.set_title('Fours and Sixes conceded by each Indian bowler')
ax.legend()
plt.xticks(rotation=45)

# Create the plot for Pakistan
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(result.loc[('PAK'), :].index, result.loc[('PAK'), :]['Fours Conceded'], width=0.4, label='Fours')
ax.bar(result.loc[('PAK'), :].index, result.loc[('PAK'), :]['Sixes Conceded'], width=0.4, label='Sixes', bottom=result.loc[('PAK'), :]['Fours Conceded'])
ax.set_ylabel('Number of runs')
ax.set_xlabel('Bowler')
ax.set_title('Fours and Sixes conceded by each Pakistan bowler')
ax.legend()
plt.xticks(rotation=45)

plt.show()
# Out:
# <style type="text/css">
# #T_c1846 th {
#   font-weight: bold;
#   font-size: 12pt;
# }
# #T_c1846 td {
#   font-size: 11pt;
# }
# ...

# %%
ind_match_id=IND_results['id']

ind_match_id
# Out:
# 0    1298178
# 1    1298176
# 2    1298169
# 3    1298164
# 4    1298157
# 5    1298150
# Name: id, dtype: int64

# %%
ind_details = details.loc[details['match_id'].isin(ind_match_id)]
ind_bowling = ind_details.loc[(ind_details['current_innings']!='INDIA') & (ind_details['wkt_text']!="")]

ind_top_bowlers = ind_bowling['bowler1_name'].value_counts()[:].index
ind_top_bowlers
# Out:
# Index(['Arshdeep Singh', 'Mohammed Shami', 'Ravichandran Ashwin',
#        'Bhuvneshwar Kumar', 'Hardik Pandya', 'Axar Patel'],
#       dtype='object', name='bowler1_name')

# %%
ind_bowling = ind_bowling.loc[ind_bowling['bowler1_name'].isin(ind_top_bowlers)]
ind_bowling = ind_bowling[['match_id','bowler1_name','bowler1_wkts']].groupby(['match_id','bowler1_name']).max().unstack()
ind_bowling=ind_bowling.cumsum()
ind_bowling
plt.figure(figsize=(10,6))
# plt.style.use('seaborn')
plt.plot(ind_bowling['bowler1_wkts','Arshdeep Singh'],color='#06283D',linewidth=2, label='Arshdeep Singh')
plt.plot(ind_bowling['bowler1_wkts','Axar Patel'],color='#FFA500',linewidth=2, label='Axar Patel')
plt.plot(ind_bowling['bowler1_wkts','Bhuvneshwar Kumar'],color='#1363DF',linewidth=2, label='Bhuvneshwar Kumar')
plt.plot(ind_bowling['bowler1_wkts','Hardik Pandya'],color='#1363DF',linewidth=2, linestyle='--', label='Hardik Pandya')
plt.plot(ind_bowling['bowler1_wkts','Mohammed Shami'],color='#FFA500',linestyle='--',linewidth=2, label='Mohammed Shami')
plt.xlabel('versus')
plt.ylabel('Total wickets')
plt.xticks(rotation=90)
plt.title("How INDIA's top 5 wicket takers fared in T20 2022")
plt.legend()
plt.grid(True)
# plt.savefig('top wicket takers.png',bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# **NOW ITS TIME FOR ENG VS AFG**

# %%
summary=pd.read_csv('ICCT202022)/summary.csv')
batting.sample(5)
# Out:
#      season  match_id  match_name home_team away_team  \
# 250    2022   1298164  INDIA v SA     INDIA        SA
# 428    2022   1298151   BAN v NED       BAN       NED
# 694    2022   1298135    NAM v SL       NAM        SL
# 219    2022   1298166    AFG v SL       AFG        SL
# 264    2022   1298164  INDIA v SA     INDIA        SA
#
#                                                 venue      city    country  \
# 250                                     Perth Stadium     Perth  Australia
# 428                            Bellerive Oval, Hobart    Hobart  Australia
# 694          Simonds Stadium, South Geelong, Victoria   Geelong  Australia
# 219  Brisbane Cricket Ground, Woolloongabba, Brisbane  Brisbane  Australia
# 264                                     Perth Stadium     Perth  Australia
#
#     current_innings  innings_id  ... fours sixes  strikeRate  captain  \
# 250           INDIA           1  ...     6     3      170.00    False
# ...

# %%
ENG_AFG_matches = summary[((summary['home_team']=='ENG') & (summary['away_team']=='AFG')) | ((summary['home_team']=='AFG') & (summary['away_team']=='AUS'))]
ENG_AFG_matches
# Out:
# Empty DataFrame
# Columns: [season, id, name, short_name, description, home_team, away_team, toss_won, decision, 1st_inning_score, 2nd_inning_score, home_score, away_score, winner, result, start_date, end_date, venue_id, venue_name, home_captain, away_captain, pom, points, super_over, home_overs, home_runs, home_wickets, home_boundaries, away_overs, away_runs, away_wickets, away_boundaries, highlights, home_key_batsman, home_key_bowler, home_playx1, away_playx1, away_key_batsman, away_key_bowler, match_days, umpire1, umpire2, tv_umpire, referee, reserve_umpire]
# Index: []
#
# [0 rows x 45 columns]

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='AUS',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                 batsman1_runs
# batsman1_name
# Aaron Finch                63
# Marcus Stoinis             59
# Glenn Maxwell              54
# Mitchell Marsh             45
# David Warner               25
# Pat Cummins                21

# %%
details['current_innings'].unique()
details.loc[details['current_innings']=='AFG',['batsman1_name','batsman1_runs']].groupby('batsman1_name').max().sort_values(by='batsman1_runs',ascending=False)[:6]
# Out:
#                     batsman1_runs
# batsman1_name
# Rashid Khan                    48
# Gulbadin Naib                  39
# Ibrahim Zadran                 32
# Rahmanullah Gurbaz             30
# Usman Ghani                    30
# Najibullah Zadran              18

# %%
summary = pd.read_csv('ICCT202022)/summary.csv', index_col=None)
details = pd.read_csv('ICCT202022)/details.csv', index_col=None)
MATCH_ID = 1298148
details['match_id'] = details['match_id'].astype(int)
details['comment_id'] = details['comment_id'].astype(int)

#Select Ball by Ball data of Ind vs Pak match
detail_match = details.query("match_id == {}".format(MATCH_ID)).reset_index(drop=True)
detail_match[['home_team','away_team','current_innings', 'innings_id','over','ball','runs','batsman1_name','bowler1_name','isBoundary','isWide','isNoball','batsman1_runs', 'batsman1_balls','bowler1_overs','bowler1_runs']].head(20)
# Out:
#    home_team away_team current_innings  innings_id  over  ball  runs  \
# 0        AFG       ENG             AFG           1     1     1     0
# 1        AFG       ENG             AFG           1     1     2     1
# 2        AFG       ENG             AFG           1     1     3     0
# 3        AFG       ENG             AFG           1     1     4     0
# 4        AFG       ENG             AFG           1     1     5     0
# 5        AFG       ENG             AFG           1     1     6     1
# 6        AFG       ENG             AFG           1     2     1     0
# 7        AFG       ENG             AFG           1     2     2     2
# 8        AFG       ENG             AFG           1     2     3     6
# 9        AFG       ENG             AFG           1     2     4     1
# 10       AFG       ENG             AFG           1     2     5     0
# 11       AFG       ENG             AFG           1     2     6     0
# 12       AFG       ENG             AFG           1     3     1     0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Filter the data for the given match_id
match_id = 1298148
match_batting = batting[batting['match_id'] == match_id]

# Group the data by batsman and sum the runs column
runs_by_batsman = match_batting.groupby('name')['runs'].sum().sort_values(ascending=False)

# Create a horizontal bar plot
fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(y=runs_by_batsman.index, width=runs_by_batsman.values)
ax.set_title(f'Runs scored by each batsman in match ID {match_id}')
ax.set_xlabel('Runs')
ax.set_ylabel('Batsman')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Filter data for ENG vs AFG match only
match_id = 1298148
batting = batting[batting['match_id'] == match_id]

# Group the data by batsman name and sum the runs column
runs_by_batsman = batting.groupby('name')['runs'].sum()

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 8))
ax.bar(x=runs_by_batsman.index, height=runs_by_batsman.values)
ax.set_title('Runs scored by each batsman in ENG vs AFG match')
ax.set_xlabel('Batsman')
ax.set_ylabel('Runs')
plt.xticks(rotation=90)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Filter data for ENG vs AFG match
match_id = 1298148
teams = ['ENG', 'AFG']
batting = batting[(batting['match_id'] == match_id) & (batting['current_innings'].isin(teams))]

# Group the data by match ID, team name, and batsman name, and sum the runs column
runs_by_team = batting.groupby(['match_id', 'current_innings', 'name'])['runs'].sum().reset_index()

# Split the data into AFG and ENG dataframes
afg_data = runs_by_team[runs_by_team['current_innings'] == 'AFG']
eng_data = runs_by_team[runs_by_team['current_innings'] == 'ENG']

# Create a horizontal bar plot for AFG
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(y=afg_data['name'], width=afg_data['runs'], color='blue')
ax.set_title(f'Runs scored by AFG batsmen in match_id {match_id}')
ax.set_xlabel('Runs')
ax.set_ylabel('Batsmen')

# Add the total runs as text on the bars
for i, (index, row) in enumerate(afg_data.iterrows()):
    ax.text(row['runs'], i, str(row['runs']), color='white', ha='right', va='center', fontweight='normal')

# Create a horizontal bar plot for ENG
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(y=eng_data['name'], width=eng_data['runs'], color='green')
ax.set_title(f'Runs scored by ENG batsmen in match_id {match_id}')
ax.set_xlabel('Runs')
ax.set_ylabel('Batsmen')

# Add the total runs as text on the bars
for i, (index, row) in enumerate(eng_data.iterrows()):
    ax.text(row['runs'], i, str(row['runs']), color='white', ha='right', va='center', fontweight='normal')

plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the batting and bowling data
batting = pd.read_csv('ICCT202022)/batting_card.csv')
bowling = pd.read_csv('ICCT202022)/bowling_card.csv')

# Get the match ID for the England vs Afghanistan match
match_id = 1298148

# Get the details of England batsmen in the match against Afghanistan
england_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['away_team'] == 'ENG') & (batting['innings_id'] == 1), ['name', 'runs']]

# Group the data by batsman name and sum the runs column
runs_by_batsman = england_batsmen.groupby('name')['runs'].sum()

# Create a bar chart of the runs scored by each batsman
fig, ax = plt.subplots()
ax.bar(runs_by_batsman.index, runs_by_batsman.values, label='England', color='blue')

# Get the details of Afghanistan batsmen in the match against England
afghanistan_batsmen = batting.loc[(batting['match_id'] == match_id) & (batting['home_team'] == 'AFG') & (batting['innings_id'] == 2), ['name', 'runs']]

# Group the data by batsman name and sum the runs column
runs_by_batsman = afghanistan_batsmen.groupby('name')['runs'].sum()

# Add the runs scored by each batsman to the existing bar chart
ax.bar(runs_by_batsman.index, runs_by_batsman.values, label='Afghanistan', color='orange')

# Set the chart title and axis labels
ax.set_title('Runs scored by batsmen in the England vs Afghanistan match')
ax.set_xlabel('Batsman')
ax.set_ylabel('Runs scored')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Add a legend to the chart
ax.legend()

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the bowling data
bowling = pd.read_csv('ICCT202022)/bowling_card.csv')

# Get the details of England bowlers in the match against Afghanistan
england_bowlers = bowling.loc[(bowling['match_id'] == 1298148) & (bowling['away_team'] == 'ENG') & (bowling['innings_id'] == 1), ['name', 'conceded']]

# Group the data by bowler name and sum the runs_conceded column
runs_by_bowler_england = england_bowlers.groupby('name')['conceded'].sum()

# Create a bar chart of the runs conceded by each bowler
fig, ax = plt.subplots()
ax.bar(runs_by_bowler_england.index, runs_by_bowler_england.values, label='England')

# Get the details of Afghanistan bowlers in the match against England
afghanistan_bowlers = bowling.loc[(bowling['match_id'] == 1298148) & (bowling['away_team'] == 'ENG') & (bowling['innings_id'] == 2), ['name', 'conceded']]

# Group the data by bowler name and sum the runs_conceded column
runs_by_bowler_afghanistan = afghanistan_bowlers.groupby('name')['conceded'].sum()

# Create a bar chart of the runs conceded by each bowler
ax.bar(runs_by_bowler_afghanistan.index, runs_by_bowler_afghanistan.values, label='Afghanistan')

# Set the chart title and axis labels
ax.set_title('Runs conceded by England and Afghanistan bowlers in the England vs Afghanistan match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Runs conceded')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Add a legend to the chart
ax.legend()

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the match ID for the Afghanistan vs England match
match_id = 1298148

# Get the details of ENG bowlers in the match against afg
eng_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'ENG') & (bowling['innings_id'] == 1), ['name', 'foursConceded','sixesConceded']]

# Get the details of Afghanistan bowlers in the match against England
afg_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'AFG') & (bowling['innings_id'] == 2), ['name', 'foursConceded' , 'sixesConceded']]

# Group the data by bowler name and sum the wickets column
wickets_by_bowler_eng = eng_bowlers.groupby('name')['foursConceded'].sum()
wickets_by_bowler_afg = afg_bowlers.groupby('name')['foursConceded'].sum()

# Create a bar chart of the wickets taken by each bowler for each team
fig, ax = plt.subplots()
ax.bar(wickets_by_bowler_eng.index, wickets_by_bowler_eng.values, label='England', color='blue')
ax.bar(wickets_by_bowler_afg.index, wickets_by_bowler_afg.values, label='Afghanistan', color='green', hatch='//')

# Set the chart title and axis labels
ax.set_title('Wickets taken by each team\'s bowlers in the match')
ax.set_xlabel('Bowler')
ax.set_ylabel('Wickets')
ax.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the match ID for the Afghanistan vs England match
match_id = 1298148

# Get the details of ENG bowlers in the match against AFG
eng_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'ENG') & (bowling['innings_id'] == 1), ['name', 'foursConceded','sixesConceded']]

# Get the details of AFG bowlers in the match against ENG
afg_bowlers = bowling.loc[(bowling['match_id'] == match_id) & (bowling['away_team'] == 'ENG') & (bowling['innings_id'] == 2), ['name', 'foursConceded' , 'sixesConceded']]

# Group the data by bowler name and sum the wickets column for ENG
wickets_by_bowler_eng = eng_bowlers.groupby('name')['foursConceded'].sum()

# Group the data by bowler name and sum the wickets column for AFG
wickets_by_bowler_afg = afg_bowlers.groupby('name')['foursConceded'].sum()

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)

# Create a bar chart of the wickets taken by each ENG bowler
ax1.bar(wickets_by_bowler_eng.index, wickets_by_bowler_eng.values, label='ENG', color='blue')

# Set the chart title and axis labels for ENG bowlers
ax1.set_title('ENG bowlers')
ax1.set_xlabel('Bowler')
ax1.set_ylabel('Wickets')
ax1.legend()

# Rotate the x-axis labels for better readability for ENG bowlers
ax1.tick_params(axis='x', rotation=90)

# Create a bar chart of the wickets taken by each AFG bowler
ax2.bar(wickets_by_bowler_afg.index, wickets_by_bowler_afg.values, label='AFG', color='green')

# Set the chart title and axis labels for AFG bowlers
ax2.set_title('AFG bowlers')
ax2.set_xlabel('Bowler')
ax2.set_ylabel('Wickets')
ax2.legend()

# Rotate the x-axis labels for better readability for AFG bowlers
ax2.tick_params(axis='x', rotation=90)

# Set the title of the overall figure
fig.suptitle('Wickets taken by each team\'s bowlers in the match')

# Show the chart
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
batting = pd.read_csv('ICCT202022)/batting_card.csv')
bowling = pd.read_csv('ICCT202022)/bowling_card.csv')

# Select the match ID
match_id = 1298148

# Get the details of all bowlers who played in the match
bowlers = bowling.loc[(bowling['match_id'] == match_id), ['name', 'overs', 'conceded', 'foursConceded', 'sixesConceded' , 'dots' , 'economyRate']]

# Calculate the number of fours and sixes conceded by each bowler
fours_by_bowler = bowlers.groupby('name')['foursConceded'].sum()
sixes_by_bowler = bowlers.groupby('name')['sixesConceded'].sum()
dots_by_bowler = bowlers.groupby('name')['dots'].sum()
economy_by_bowler = bowlers.groupby('name')['economyRate'].sum()

# Calculate the number of overs bowled by each bowler
overs_by_bowler = bowlers.groupby('name')['overs'].sum()
result = pd.DataFrame({'Fours Conceded': fours_by_bowler, 'Sixes Conceded': sixes_by_bowler, 'Overs Bowled': overs_by_bowler, 'dots bowled': dots_by_bowler, 'Economy': economy_by_bowler})

# Format the data for display
result_data = result.copy()
result_data = result_data.rename(columns={'dots bowled': 'Dots Bowled'})
result_data = result_data.astype({'Fours Conceded': int, 'Sixes Conceded': int, 'Dots Bowled': float, 'Economy': float})
result_data = result_data.style.format({
    'Fours Conceded': '{:.0f}',
    'Sixes Conceded': '{:.0f}',
    'Overs Bowled': '{:.1f}',
    'Dots Bowled': '{:.1f}'
})

# Set table properties
result_data.set_properties(**{'text-align': 'center'})
result_data.set_table_styles([{'selector': 'th', 'props': [('font-weight', 'bold'), ('font-size', '12pt')]},
                              {'selector': 'td', 'props': [('font-size', '11pt')]}
])

# Display the table
display(result_data)

# Create the plot for Afghanistan
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(result.loc[('AFG'), :].index, result.loc[('AFG'), :]['Fours Conceded'], width=0.4, label='Fours')
ax.bar(result.loc[('AFG'), :].index, result.loc[('AFG'), :]['Sixes Conceded'], width=0.4, label='Sixes', bottom=result.loc[('AFG'), :]['Fours Conceded'])
ax.set_ylabel('Number of runs')
ax.set_xlabel('Bowler')
ax.set_title('Fours and Sixes conceded by each Afghanistan bowler')
ax.legend()
plt.xticks(rotation=45)
# Out:
# <style type="text/css">
# #T_aa27f th {
#   font-weight: bold;
#   font-size: 12pt;
# }
# #T_aa27f td {
#   font-size: 11pt;
# }
# ...

# %%
import pandas as pd

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Create a new dataframe to store the average batting performance of each player for each team
team_player_avg = pd.DataFrame(columns=['Team', 'Player', 'Batting Average'])

# Loop through each team
for team in ['INDIA', 'PAK', 'ENG', 'AFG']:
    # Get the list of players from the current team
    players = list(batting.loc[batting['current_innings'] == team, 'name'].unique())
    
    # Calculate the batting average for each player and store it in the team_player_avg dataframe
    for player in players:
        avg = batting.loc[(batting['current_innings'] == team) & (batting['name'] == player), 'runs'].mean()
        team_player_avg = team_player_avg.append({'Team': team, 'Player': player, 'Batting Average': avg}, ignore_index=True)

# Print the team_player_avg dataframe sorted by batting average in descending order
print(team_player_avg.sort_values(by='Batting Average', ascending=False))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Create a new dataframe to store the average batting performance of each player for each team
team_player_avg = pd.DataFrame(columns=['Team', 'Player', 'Batting Average'])

# Loop through each team
for team in ['INDIA', 'PAK', 'ENG', 'AFG']:
    # Get the list of players from the current team
    players = list(batting.loc[batting['current_innings'] == team, 'name'].unique())

    # Calculate the batting average for each player and store it in the team_player_avg dataframe
    for player in players:
        avg = batting.loc[(batting['current_innings'] == team) & (batting['name'] == player), 'runs'].mean()
        team_player_avg = team_player_avg.append({'Team': team, 'Player': player, 'Batting Average': avg}, ignore_index=True)

# Sort the team_player_avg dataframe by batting average in descending order
team_player_avg = team_player_avg.sort_values(by='Batting Average', ascending=False)

# Create a barplot of batting average for each player
plt.figure(figsize=(10, 6))
sns.barplot(x='Player', y='Batting Average', hue='Team', data=team_player_avg)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.xlabel('Player', fontsize=10)
plt.ylabel('Batting Average', fontsize=10)
plt.title('Batting Averages for Players by Team')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26224\2039273832.py in ?()
#      15
#      16     # Calculate the batting average for each player and store it in the team_player_avg dataframe
#      17     for player in players:
#      18         avg = batting.loc[(batting['current_innings'] == team) & (batting['name'] == player), 'runs'].mean()
# ---> 19         team_player_avg = team_player_avg.append({'Team': team, 'Player': player, 'Batting Average': avg}, ignore_index=True)
#      20
#      21 # Sort the team_player_avg dataframe by batting average in descending order
#      22 team_player_avg = team_player_avg.sort_values(by='Batting Average', ascending=False)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/batting_card.csv')

# Create a new dataframe to store the runs scored and balls faced by each player for each team
team_player_performance = pd.DataFrame(columns=['Team', 'Player', 'Runs', 'Balls Faced'])

# Loop through each team
for team in ['INDIA', 'PAK', 'ENG', 'AFG']:
    # Get the list of players from the current team
    players = list(batting.loc[batting['current_innings'] == team, 'name'].unique())

    # Add the runs and balls faced for each player to the team_player_performance dataframe
    for player in players:
        runs = batting.loc[(batting['current_innings'] == team) & (batting['name'] == player), 'runs'].sum()
        balls_faced = batting.loc[(batting['current_innings'] == team) & (batting['name'] == player), 'ballsFaced'].sum()
        team_player_performance = pd.concat([team_player_performance, pd.DataFrame({'Team': team, 'Player': player, 'Runs': runs, 'Balls Faced': balls_faced}, index=[0])], ignore_index=True)

# Calculate the strike rate for each player and add it to the team_player_performance dataframe
team_player_performance['Strike Rate'] = 0
for i, row in team_player_performance.iterrows():
    if row['Balls Faced'] > 0:
        team_player_performance.at[i, 'Strike Rate'] = 100 * row['Runs'] / row['Balls Faced']

# Create a scatter plot of strike rate vs runs for each team
colors = {'INDIA': 'blue', 'PAK': 'green', 'ENG': 'red', 'AFG': 'orange'}
for team in ['INDIA', 'PAK', 'ENG', 'AFG']:
    team_data = team_player_performance.loc[team_player_performance['Team'] == team]
    plt.scatter(team_data['Runs'], team_data['Strike Rate'], c=colors[team], label=team)

# Add a legend and axis labels
plt.legend()
plt.xlabel('Runs')
plt.ylabel('Strike Rate')

# Show the plot
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Select the match ID
match_id = 1298148

# Get the details of all bowlers who played in the match
bowlers = bowling.loc[(bowling['match_id'] == match_id), ['name', 'overs', 'conceded', 'foursConceded', 'sixesConceded' , 'dots' , 'economyRate']]

# Calculate the number of fours and sixes conceded by each bowler
fours_by_bowler = bowlers.groupby('name')['foursConceded'].sum()
sixes_by_bowler = bowlers.groupby('name')['sixesConceded'].sum()
dots_by_bowler = bowlers.groupby('name')['dots'].sum()
economy_by_bowler = bowlers.groupby('name')['economyRate'].sum()

# Calculate the number of overs bowled by each bowler
overs_by_bowler = bowlers.groupby('name')['overs'].sum()

# Merge the results into a single DataFrame
result = pd.concat([fours_by_bowler, sixes_by_bowler, overs_by_bowler ,dots_by_bowler,economy_by_bowler], axis=1, sort=False)
result.columns = ['Fours Conceded', 'Sixes Conceded', 'Overs Bowled' , 'dots bowled' , 'Economy']

# Format the data for display
result = result.style.format({
    'Fours Conceded': '{:.0f}',
    'Sixes Conceded': '{:.0f}',
    'Overs Bowled': '{:.1f}',
    'dots Bowled': '{:.1f}'
})

# Set table properties
result.set_properties(**{'text-align': 'center'})
result.set_table_styles([
    {'selector': 'th', 'props': [('font-weight', 'bold'), ('font-size', '12pt')]},
    {'selector': 'td', 'props': [('font-size', '11pt')]}
])

# Display the table
display(result)
# Create the plot for India
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(result.loc[('INDIA'), :].index, result.loc[('INDIA'), :]['Fours Conceded'], width=0.4, label='Fours')
ax.bar(result.loc[('INDIA'), :].index, result.loc[('INDIA'), :]['Sixes Conceded'], width=0.4, label='Sixes', bottom=result.loc[('INDIA'), :]['Fours Conceded'])
ax.set_ylabel('Number of runs')
ax.set_xlabel('Bowler')
ax.set_title('Fours and Sixes conceded by each Indian bowler')
ax.legend()
plt.xticks(rotation=45)

# Create the plot for Pakistan
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(result.loc[('PAK'), :].index, result.loc[('PAK'), :]['Fours Conceded'], width=0.4, label='Fours')
ax.bar(result.loc[('PAK'), :].index, result.loc[('PAK'), :]['Sixes Conceded'], width=0.4, label='Sixes', bottom=result.loc[('PAK'), :]['Fours Conceded'])
ax.set_ylabel('Number of runs')
ax.set_xlabel('Bowler')
ax.set_title('Fours and Sixes conceded by each Pakistan bowler')
ax.legend()
plt.xticks(rotation=45)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the batting dataset
batting = pd.read_csv('ICCT202022)/summary.csv')

# Calculate the average runs scored by each team in each match
team_match_avg = pd.pivot_table(batting, values='home_runs', index='home_team', columns='short_name', aggfunc='mean')

# Create the heatmap using seaborn
plt.figure(figsize=(20, 8))
sns.heatmap(team_match_avg, cmap='YlGnBu')
plt.title('Average Runs Scored by Each Team in Each Match')
plt.xlabel('Match Number')
plt.ylabel('Team')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...
